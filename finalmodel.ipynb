# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("housing.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df = data.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.hist (figsize= (16, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
df1 = df.drop("ocean_proximity",axis=1)

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
plt.figure(figsize = (16,8))
sns.heatmap(df1.corr(), annot= True, cmap='coolwarm' )
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

x = df1.drop(['median_house_value'], axis= 1)
y= df1['median_house_value']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =.25)

# %%
plt.hist(y, bins= 25)
# Out:
# (array([   5.,   11.,   50.,  666., 1612., 3003., 4468., 4782., 3330.,
#         2506.]),
#  array([13.8725787 , 14.37847797, 14.88437725, 15.39027652, 15.8961758 ,
#         16.40207508, 16.90797435, 17.41387363, 17.9197729 , 18.42567218,
#         18.93157145]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.log2(y))
# Out:
# (array([   5.,   11.,   50.,  666., 1612., 3003., 4468., 4782., 3330.,
#         2506.]),
#  array([13.8725787 , 14.37847797, 14.88437725, 15.39027652, 15.8961758 ,
#         16.40207508, 16.90797435, 17.41387363, 17.9197729 , 18.42567218,
#         18.93157145]),
#  <BarContainer object of 10 artists>)

# %%
location = df1.copy()

location.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1)
location.plot(kind="scatter", x="longitude", y="latitude", alpha=0.5,
             s=housing["population"]/100, label="Population", figsize=(12, 8),
             c="median_house_value", cmap=plt.get_cmap("coolwarm"), colorbar=True)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train.values,y_train.values)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test.values,y_test.values)
# Out:
# 0.8040840369632423

# %%
def prediction_calculator(longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income) :

    prediction = forest.predict([[
        longitude, 
        latitude, 
        housing_median_age, 
        total_rooms, 
        total_bedrooms, 
        population,
        households,
        median_income]])
    return prediction

# %%
prediction_calculator(-122.23,37.88,41.0,880.0,129.0,322.0,126.0,8.3252,)
# Out:
# array([450674.13])

# %%
pred_data = prediction_calculator(-122.23,37.88,41.0,880.0,129.0,322.0,126.0,8.3252,)
print("The model predicts a median house value of :", pred_data , " for an area with these features")
# Out:
# The model predicts a median house value of : [450674.13]  for an area with these features
